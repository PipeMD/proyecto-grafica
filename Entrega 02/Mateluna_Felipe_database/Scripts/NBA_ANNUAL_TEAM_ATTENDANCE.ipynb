# %%
import pandas as pd

df = pd.read_csv('/content/NBA ANNUAL TEAMS ATTENDANCE ESPN.csv')

display(df)

# %%
df.isnull()
# Out:
#       Year     RK   Team  Home GMS  Home Total Attendance  \
# 0    False  False  False     False                  False
# 1    False  False  False     False                  False
# 2    False  False  False     False                  False
# 3    False  False  False     False                  False
# 4    False  False  False     False                  False
# ..     ...    ...    ...       ...                    ...
# 303  False  False  False     False                  False
# 304  False  False  False     False                  False
# 305  False  False  False     False                  False
# 306  False  False  False     False                  False
# 307  False  False  False     False                  False
#
#      Home AVG Attendance  Home PCT Attendance  Road GMS  Road AVG Attendance  \
# 0                  False                 True     False                False
# 1                  False                False     False                False
# 2                  False                False     False                False
# 3                  False                False     False                False
# 4                  False                False     False                False
# ..                   ...                  ...       ...                  ...
# 303                False                False     False                False
# 304                False                False     False                False
# 305                False                False     False                False
# 306                False                False     False                False
# 307                False                False     False                False
#
#      Road PCT Attendance  Overall GMS  Overall AVG Attendance  \
# 0                   True        False                   False
# 1                  False        False                   False
# 2                  False        False                   False
# 3                  False        False                   False
# 4                  False        False                   False
# ..                   ...          ...                     ...
# 303                False        False                   False
# 304                False        False                   False
# 305                False        False                   False
# 306                False        False                   False
# 307                False        False                   False
#
#      Overall PCT Attendance
# 0                      True
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ..                      ...
# 303                   False
# 304                   False
# 305                   False
# 306                   False
# 307                   False
#
# [308 rows x 13 columns]

# %%
# Reemplazar datos Mavericks

filas_a_modificar = [143]


mavericks_home_pct_attendance = 105.1
df.loc[filas_a_modificar, 'Home PCT Attendance'] = mavericks_home_pct_attendance

mavericks_road_pct_attendance = 97.1
df.loc[filas_a_modificar, 'Road PCT Attendance'] = mavericks_road_pct_attendance

mavericks_overall_pct_attendance = 101.1
df.loc[filas_a_modificar, 'Overall PCT Attendance'] = mavericks_overall_pct_attendance

# Reemplazar datos Rockets

filas_a_modificar_2 = [220]

rockets_home_pct_attendance = 99.2
df.loc[filas_a_modificar_2, 'Home PCT Attendance'] = rockets_home_pct_attendance

rockets_road_pct_attendance = 96.7
df.loc[filas_a_modificar_2, 'Road PCT Attendance'] = rockets_road_pct_attendance

rockets_overall_pct_attendance = 97.9
df.loc[filas_a_modificar_2, 'Overall PCT Attendance'] = rockets_overall_pct_attendance

print (df)

# %%
display(df)

# %%
df.bfill()
# Out:
#      Year    RK     Team  Home GMS  Home Total Attendance  \
# 0    2024   3.0    76ers        41                821.714
# 1    2023   2.0    76ers        41                839.261
# 2    2022   2.0    76ers        41                846.867
# 3    2021   2.0    76ers        36                 68.583
# 4    2020   1.0    76ers        35                639.491
# ..    ...   ...      ...       ...                    ...
# 303  2018  14.0  Wizards        41                718.946
# 304  2017  20.0  Wizards        41                697.107
# 305  2016  16.0  Wizards        41                725.426
# 306  2015  13.0  Wizards        41                747.796
# 307  2014  18.0  Wizards        41                698.068
#
#      Home AVG Attendance  Home PCT Attendance  Road GMS  Road AVG Attendance  \
# 0                 20.041                 97.5        41               18.395
# 1                 20.469                 97.5        41               17.910
# 2                 20.655                 98.4        41               16.589
# 3                  3.810                 18.1        36                2.693
# 4                 20.628                102.4        38               17.706
# ..                   ...                  ...       ...                  ...
# 303               17.973                 88.6        41               17.682
# 304               17.002                 83.8        41               17.949
# 305               17.693                 87.3        41               17.787
# 306               18.238                 89.9        41               18.253
# 307               17.026                 84.0        41               17.183
#
#      Road PCT Attendance  Overall GMS  Overall AVG Attendance  \
# 0                   95.2           82                  19.218
# 1                   95.2           82                  19.190
# 2                   87.4           82                  18.622
# 3                   14.5           72                   3.284
# 4                   94.5           73                  19.122
# ..                   ...          ...                     ...
# 303                 92.1           82                  17.826
# 304                 93.5           82                  17.476
# 305                 92.4           82                  17.740
# 306                 95.0           82                  18.246
# 307                 89.2           82                  17.104
#
#      Overall PCT Attendance
# 0                      96.4
# 1                      96.4
# 2                      93.2
# 3                      16.5
# 4                      98.4
# ..                      ...
# 303                    90.3
# 304                    88.5
# 305                    89.8
# 306                    92.4
# 307                    86.5
#
# [308 rows x 13 columns]
